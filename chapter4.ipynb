# %% [markdown]
# # Chapter 4 Geocentric models

# %% [markdown]
# Jeg læser Statistical Rethinking af Richard McElreath. Titlen er virkelig sigende. Jeg har i sin tid taget bifag i statistik fra Københavns Universitet. Som jeg husker det kom vi ikke i detaljer ind på de forskellige retninger for statistisk inferens.  Undervisningen var primært tilrettelagt med udgangspunkt i likelihoodfunktionen og ikke bayesianske metoder. Statistical Rethinking er om inferens fra en bayesiansk vinkel. Og det kræver virkelig en helt ny måde at tænke på. Se mere her <a target="_blank" href="https://colab.research.google.com/github/carsten-j/Rethinking/blob/main/chapter4.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a> og ræk endelig ud, hvis du spotter fejl eller noget som kan forbedres.

# %% [markdown]
# This notebook implements most parts of section 4.3 and 4.4 from Statistical Rethinking, 2nd ed. by Richard McElreath. The example code in the book is written in R. Here I try to create similar functionality using Python.
#
# The notebook is not meant to be self-contained. I try to give references to the code samples in the book, but you really need to have the book to follow along.
#
# Please note that the `QuadraticApproximation` class occasiaonlly fails due to the (random) matrix $H$ not being symmetric positive semidefinite. If it happens just try re-running the cell.

# %% [markdown]
# ## 4.3. Gaussian model of height

# %%
import sys

# %%
# latest PreliZ might not be installed
try:
    import preliz as pz
except ImportError as error:
    # !{sys.executable} -m pip install preliz
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
try:
    import watermark as wm
except ImportError as error:
    # !{sys.executable} -m pip install watermark

# %%
# !pip install quad5==0.1.8
# Out:
# Collecting quad5==0.1.8
#   Downloading quad5-0.1.8-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: PYMC==5.15.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from quad5==0.1.8) (5.15.0)
# Requirement already satisfied: arviz>=0.13.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from PYMC==5.15.0->quad5==0.1.8) (0.18.0)
# Requirement already satisfied: cachetools>=4.2.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from PYMC==5.15.0->quad5==0.1.8) (5.3.3)
# Requirement already satisfied: cloudpickle in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from PYMC==5.15.0->quad5==0.1.8) (3.0.0)
# Requirement already satisfied: numpy>=1.15.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from PYMC==5.15.0->quad5==0.1.8) (1.26.4)
# Requirement already satisfied: pandas>=0.24.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from PYMC==5.15.0->quad5==0.1.8) (2.2.2)
# Requirement already satisfied: pytensor<2.21,>=2.20 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from PYMC==5.15.0->quad5==0.1.8) (2.20.0)
# Requirement already satisfied: rich>=13.7.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from PYMC==5.15.0->quad5==0.1.8) (13.7.1)
# Requirement already satisfied: scipy>=1.4.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from PYMC==5.15.0->quad5==0.1.8) (1.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from PYMC==5.15.0->quad5==0.1.8) (4.11.0)
# Requirement already satisfied: setuptools>=60.0.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from arviz>=0.13.0->PYMC==5.15.0->quad5==0.1.8) (68.2.2)
# Requirement already satisfied: matplotlib>=3.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from arviz>=0.13.0->PYMC==5.15.0->quad5==0.1.8) (3.9.0)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from arviz>=0.13.0->PYMC==5.15.0->quad5==0.1.8) (23.2)
# Requirement already satisfied: dm-tree>=0.1.8 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from arviz>=0.13.0->PYMC==5.15.0->quad5==0.1.8) (0.1.8)
# Requirement already satisfied: xarray>=2022.6.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from arviz>=0.13.0->PYMC==5.15.0->quad5==0.1.8) (2024.5.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from arviz>=0.13.0->PYMC==5.15.0->quad5==0.1.8) (1.3.0)
# Requirement already satisfied: xarray-einstats>=0.3 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from arviz>=0.13.0->PYMC==5.15.0->quad5==0.1.8) (0.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pandas>=0.24.0->PYMC==5.15.0->quad5==0.1.8) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pandas>=0.24.0->PYMC==5.15.0->quad5==0.1.8) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pandas>=0.24.0->PYMC==5.15.0->quad5==0.1.8) (2024.1)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pytensor<2.21,>=2.20->PYMC==5.15.0->quad5==0.1.8) (3.14.0)
# Requirement already satisfied: etuples in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pytensor<2.21,>=2.20->PYMC==5.15.0->quad5==0.1.8) (0.3.9)
# Requirement already satisfied: logical-unification in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pytensor<2.21,>=2.20->PYMC==5.15.0->quad5==0.1.8) (0.4.6)
# Requirement already satisfied: miniKanren in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pytensor<2.21,>=2.20->PYMC==5.15.0->quad5==0.1.8) (1.0.3)
# Requirement already satisfied: cons in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pytensor<2.21,>=2.20->PYMC==5.15.0->quad5==0.1.8) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from rich>=13.7.1->PYMC==5.15.0->quad5==0.1.8) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from rich>=13.7.1->PYMC==5.15.0->quad5==0.1.8) (2.18.0)
# Requirement already satisfied: h5py in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from h5netcdf>=1.0.2->arviz>=0.13.0->PYMC==5.15.0->quad5==0.1.8) (3.11.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->PYMC==5.15.0->quad5==0.1.8) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->PYMC==5.15.0->quad5==0.1.8) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->PYMC==5.15.0->quad5==0.1.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->PYMC==5.15.0->quad5==0.1.8) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->PYMC==5.15.0->quad5==0.1.8) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->PYMC==5.15.0->quad5==0.1.8) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->PYMC==5.15.0->quad5==0.1.8) (3.1.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=0.24.0->PYMC==5.15.0->quad5==0.1.8) (1.16.0)
# Requirement already satisfied: toolz in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from logical-unification->pytensor<2.21,>=2.20->PYMC==5.15.0->quad5==0.1.8) (0.12.1)
# Requirement already satisfied: multipledispatch in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from logical-unification->pytensor<2.21,>=2.20->PYMC==5.15.0->quad5==0.1.8) (1.0.0)
# Downloading quad5-0.1.8-py3-none-any.whl (4.9 kB)
# Installing collected packages: quad5
#   Attempting uninstall: quad5
#     Found existing installation: quad5 0.1.7
#     Uninstalling quad5-0.1.7:
#       Successfully uninstalled quad5-0.1.7
# Successfully installed quad5-0.1.8

# %%
# !pip install pymc==5.15.0
# Out:
# Requirement already satisfied: pymc==5.15.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (5.15.0)
# Requirement already satisfied: arviz>=0.13.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pymc==5.15.0) (0.18.0)
# Requirement already satisfied: cachetools>=4.2.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pymc==5.15.0) (5.3.3)
# Requirement already satisfied: cloudpickle in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pymc==5.15.0) (3.0.0)
# Requirement already satisfied: numpy>=1.15.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pymc==5.15.0) (1.26.4)
# Requirement already satisfied: pandas>=0.24.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pymc==5.15.0) (2.2.2)
# Requirement already satisfied: pytensor<2.21,>=2.20 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pymc==5.15.0) (2.20.0)
# Requirement already satisfied: rich>=13.7.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pymc==5.15.0) (13.7.1)
# Requirement already satisfied: scipy>=1.4.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pymc==5.15.0) (1.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pymc==5.15.0) (4.11.0)
# Requirement already satisfied: setuptools>=60.0.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from arviz>=0.13.0->pymc==5.15.0) (68.2.2)
# Requirement already satisfied: matplotlib>=3.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from arviz>=0.13.0->pymc==5.15.0) (3.9.0)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from arviz>=0.13.0->pymc==5.15.0) (23.2)
# Requirement already satisfied: dm-tree>=0.1.8 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from arviz>=0.13.0->pymc==5.15.0) (0.1.8)
# Requirement already satisfied: xarray>=2022.6.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from arviz>=0.13.0->pymc==5.15.0) (2024.5.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from arviz>=0.13.0->pymc==5.15.0) (1.3.0)
# Requirement already satisfied: xarray-einstats>=0.3 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from arviz>=0.13.0->pymc==5.15.0) (0.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pandas>=0.24.0->pymc==5.15.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pandas>=0.24.0->pymc==5.15.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pandas>=0.24.0->pymc==5.15.0) (2024.1)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pytensor<2.21,>=2.20->pymc==5.15.0) (3.14.0)
# Requirement already satisfied: etuples in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pytensor<2.21,>=2.20->pymc==5.15.0) (0.3.9)
# Requirement already satisfied: logical-unification in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pytensor<2.21,>=2.20->pymc==5.15.0) (0.4.6)
# Requirement already satisfied: miniKanren in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pytensor<2.21,>=2.20->pymc==5.15.0) (1.0.3)
# Requirement already satisfied: cons in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from pytensor<2.21,>=2.20->pymc==5.15.0) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from rich>=13.7.1->pymc==5.15.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from rich>=13.7.1->pymc==5.15.0) (2.18.0)
# Requirement already satisfied: h5py in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from h5netcdf>=1.0.2->arviz>=0.13.0->pymc==5.15.0) (3.11.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->pymc==5.15.0) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc==5.15.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc==5.15.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc==5.15.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc==5.15.0) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc==5.15.0) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc==5.15.0) (3.1.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=0.24.0->pymc==5.15.0) (1.16.0)
# Requirement already satisfied: toolz in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from logical-unification->pytensor<2.21,>=2.20->pymc==5.15.0) (0.12.1)
# Requirement already satisfied: multipledispatch in /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages (from logical-unification->pytensor<2.21,>=2.20->pymc==5.15.0) (1.0.0)

# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import quad5 as quad5
import scipy.stats as st
import seaborn as sns
import xarray as xr
from numpy.linalg import inv
from scipy.stats import norm, uniform

# %%
# %load_ext watermark

# %%
# %watermark -a "Carsten Jørgensen" -u -d -v -m
# Out:
# Author: Carsten Jørgensen
#
# Last updated: 2024-05-23
#
# Python implementation: CPython
# Python version       : 3.10.13
# IPython version      : 8.24.0
#
# Compiler    : Clang 16.0.6
# OS          : Darwin
# Release     : 23.4.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 11
# Architecture: 64bit

# %%
RANDOM_SEED = 3137
rng = np.random.default_rng(RANDOM_SEED)

# %%
# az.style.use("arviz-white")
xr.set_options(display_expand_data=False, display_expand_attrs=False);

# %% [markdown]
# ![asdf](https://images.routledge.com/common/jackets/crclarge/978020230/9780202306490.jpg)
#
# The dataset originates from a lassic study of the population of the Bushmen of the Kalahari Deselt of Botswana done by Nancy Howell. Read more in the [book](https://www.routledge.com/Demography-of-the-Dobe-Kung/Howell/p/book/9780202306490) also by Nancy Howell.
#
# Number of rows: 544
#
# Variables:
#
#  * height in cm (float)
#  * weight in kg (float)
#  * age in years (int)
#  * male indicator (int)

# %%
d = pd.read_csv(
    "https://raw.githubusercontent.com/rmcelreath/rethinking/master/data/Howell1.csv",
    sep=";",
)

# %%
d.head(5)
# Out:
#     height     weight   age  male
# 0  151.765  47.825606  63.0     1
# 1  139.700  36.485807  63.0     0
# 2  136.525  31.864838  65.0     0
# 3  156.845  53.041914  41.0     1
# 4  145.415  41.276872  51.0     0

# %%
d.describe(percentiles=[0.055, 0.945])
# Out:
#            height      weight         age        male
# count  544.000000  544.000000  544.000000  544.000000
# mean   138.263596   35.610618   29.344393    0.472426
# std     27.602448   14.719178   20.746888    0.499699
# min     53.975000    4.252425    0.000000    0.000000
# 5.5%    81.108550    9.360721    1.000000    0.000000
# 50%    148.590000   40.057844   27.000000    0.000000
# 94.5%  165.735000   54.502894   66.135000    1.000000
# max    179.070000   62.992589   88.000000    1.000000

# %%
d2 = d[d.age >= 18]

# %%
d2.describe(percentiles=[0.055, 0.945])
# Out:
#            height      weight         age        male
# count  352.000000  352.000000  352.000000  352.000000
# mean   154.597093   44.990486   41.138494    0.468750
# std      7.742332    6.456708   15.967855    0.499733
# min    136.525000   31.071052   18.000000    0.000000
# 5.5%   142.875000   35.137504   20.000000    0.000000
# 50%    154.305000   44.792210   39.000000    0.000000
# 94.5%  167.005000   55.765876   70.000000    1.000000
# max    179.070000   62.992589   88.000000    1.000000

# %%
def prior_samples(mean, std, uniform_upper, size):
    sample_mu = norm.rvs(loc=mean, scale=std, size=size)
    sample_sigma = uniform.rvs(loc=0, scale=uniform_upper, size=size)
    prior = norm.rvs(loc=sample_mu, scale=sample_sigma)
    return prior

# %%
mean = 178.0
sigma = 20.0
uniform_upper = 50.0
n_samples = 1000

# %%
prior_20 = prior_samples(mean, sigma, uniform_upper, n_samples)
prior_100 = prior_samples(mean, 100.0, uniform_upper, n_samples)

# %% [markdown]
# Figure 4.3. Prior predictive simulation for the height model. Top row
# Prior distributions for $\mu$ and $\sigma$. The solid black line for $\mu$ is the 89% HDI
# Bottom left: The prior predictive simulation for height, using the priors in
# the top row. Values at 3 standard deviations shown on horizontal axis.
# Bottom right: Prior predictive simulation using $\mu \sim$ Normal(178, 100)
# For $\sigma=100$ we see lots of observations below zero and above 272 (world tallest man).

# %% [markdown]
# R code 4.12, 4.13, 4.14

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 8), layout="constrained")

# top left
pz.Normal(mu=mean, sigma=sigma).plot_pdf(
    pointinterval=True,
    legend="title",
    interval="quantiles",
    levels=[0.055, 0.5, 0.945],
    ax=ax[0, 0],
)
ax[0, 0].set(ylabel="Density", xlabel="mu", yticks=(0, 0.01, 0.02))

# top right
pz.Uniform(lower=0, upper=uniform_upper).plot_pdf(legend="title", ax=ax[0, 1])
ax[0, 1].set(ylabel="Density", xlabel="sigma", yticks=(0, 0.01, 0.02))

# buttom left
az.plot_kde(prior_20, ax=ax[1, 0])
ax[1, 0].set(
    title=r"h $\sim$ Normal(mu, sigma)",
    ylabel="Density",
    xlabel="height",
    yticks=(0, 0.004, 0.008, 0.012),
    xticks=(0, 73, 178, 283),
)

# buttom right
az.plot_kde(prior_100, ax=ax[1, 1])
ax[1, 1].set(
    title=r"h $\sim$ Normal(mu, sigma)" + "\n" + r"mu $\sim$ Normal(178, 100)",
    ylabel="Density",
    xlabel="height",
    xticks=(-128, 0, 178, 272, 484),
    yticks=(0, 0.002, 0.004),
)
ax[1, 1].vlines(
    x=0, ymin=0, ymax=0.004, linestyle="dashed", color="black", linewidth=0.75
)
ax[1, 1].vlines(
    x=272,
    ymin=0,
    ymax=0.004,
    linestyle="solid",
    color="black",
    alpha=0.5,
    linewidth=0.5,
)

fig.tight_layout()
# Out:
# /var/folders/fy/zx0sb02j5rv66mcpx65ldmvc0000gn/T/ipykernel_44460/3589825753.py:49: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()

# %% [markdown]
# ### Prior predictive simulation
#
# Quoting from Statistical Rethinking page 83
#
# > Prior predictive simulation is very useful for assigning sensible priors, because it can be quite hard to anticipate how priors influence the observable variables.
#
# and again from page 84
#
# > The important thing is that your prior not be based on the values in the data, but only on what you know about the data before you see it.
#
# Python has a library called [PreliZ](https://preliz.readthedocs.io/en/latest/index.html) that is a tool-box for prior elicitation. One feature is called “[prior predictive assistant](https://preliz.readthedocs.io/en/latest/examples/observed_space_examples.html#prior-predictive-assistant)” (or PPA for short). Note this a still under development. PPA has several goals one of them being
#
# > We want to select distributions based on prior information and NOT based on the observed data we want to fit.
#
# Please consult the official documention for further information.

# %%
def a_preliz_model():
    mu = pz.Normal(mu=178, sigma=20).rvs()
    sigma = pz.Uniform(lower=0, upper=50).rvs()
    y = pz.Normal(mu, sigma).rvs(100)
    return mu, sigma, y

# %%
pz.ppa(a_preliz_model)
# Out:
# "This is an experimental method under development, use with caution.
# RuntimeError: To run ppa, you need use the magic `%matplotlib widget`
# HBox(children=(Text(value='0', description='references: ', layout=Layout(margin='0 20px 0 0', width='230px'), …

# %% [markdown]
# ### 4.3.3 Grid approximation of the posterior distribution.

# %% [markdown]
# R code 4.16

# %%
mu_list = np.linspace(150, 160, 200)
sigma_list = np.linspace(7, 9, 200)

# Priors
mu_prior = st.norm(178, 20).logpdf(mu_list)
sigma_prior = st.norm(0, 50).logpdf(sigma_list)

# Likelihood
posterior = (
    st.norm(mu_list.reshape(-1, 1, 1), sigma_list.reshape(1, -1, 1))
    .logpdf(d2.height)
    .sum(axis=2)
    # Priors
    + mu_prior
    + sigma_prior
)

# Numerical trick to avoid overfloat. See Statistical Rethinking note 73
posterior = np.exp(posterior - posterior.max())

# %% [markdown]
# R code 4.17, 4.18

# %%
fig, axes = plt.subplots(ncols=2, figsize=(9, 5), sharex=True, sharey=True)
X, Y = np.meshgrid(mu_list, sigma_list)

axes[0].contourf(X, Y, posterior)
axes[0].set(xlabel=r"$\mu$", ylabel=r"$\sigma$", title="Contour plot of posterior")

axes[1].pcolormesh(X, Y, posterior)
axes[1].set(xlabel=r"$\mu$", ylabel=r"$\sigma$", title="Heat map of posterior")

fig.tight_layout()

# %%
posterior /= posterior.sum()

# %%
# Flatten the 2D array
flattened_probabilities = posterior.flatten()
# Sample indices from the flattened array
sampled_indices_flat = np.random.choice(
    flattened_probabilities.size, p=flattened_probabilities, size=10000
)
# Reshape sampled indices back to 2D
sampled_indices_2d = np.unravel_index(sampled_indices_flat, posterior.shape)

# %% [markdown]
# In Statistical Rethinking a scatterplot is used to visualize the posterior distribution. Personally I tend
# to prefer a hexbin plot. What would be your choice?

# %%
fig, ax = plt.subplots(ncols=2, figsize=(9, 5))
ax[0].hexbin(
    x=mu_list[sampled_indices_2d[0]], y=sigma_list[sampled_indices_2d[1]], gridsize=40
)
ax[0].set(xlabel=r"$\mu$", ylabel=r"$\sigma$", title="Hexbin plot of posterior")
ax[1].scatter(
    x=mu_list[sampled_indices_2d[0]],
    y=sigma_list[sampled_indices_2d[1]],
    alpha=0.1,
    marker=".",
    linewidth=0.1,
)
fig.tight_layout()

# %% [markdown]
# Yet another visualization would be to include the marginal distribution in the plot. You can do that with Seaborn.

# %%
sns.jointplot(
    x=mu_list[sampled_indices_2d[0]], y=sigma_list[sampled_indices_2d[1]], kind="hex"
);

# %%
fig, ax = plt.subplots(ncols=2, figsize=(9, 5))
az.plot_posterior(mu_list[sampled_indices_2d[0]], ax=ax[0])
ax[0].set(title=r"$\mu$")
az.plot_posterior(sigma_list[sampled_indices_2d[1]], ax=ax[1])
ax[1].set(title=r"$\sigma$")
fig.suptitle(r"Marginal posterior densities of $\mu$ and $\sigma$")
fig.tight_layout()

# %% [markdown]
# #### Posterior compatibility intervals:

# %% [markdown]
# R code 4.22

# %%
print(az.hdi(mu_list[sampled_indices_2d[0]]))
print(az.hdi(sigma_list[sampled_indices_2d[0]]))
# Out:
# [153.81909548 155.32663317]
# [7.7638191  8.06532663]

# %% [markdown]
# R code 4.23

# %%
d3 = d2.sample(n=20)

# %% [markdown]
# R code 4.24

# %%
mu_list = np.linspace(150, 170, 200)
sigma_list = np.linspace(4, 20, 200)

post2 = (
    # Likelihood
    st.norm(mu_list.reshape(-1, 1, 1), sigma_list.reshape(1, -1, 1))
    .logpdf(d3.height)
    .sum(axis=2)
    # Priors
    + st.norm(178, 20).logpdf(mu_list)
    + st.norm(0, 50).logpdf(sigma_list)
)

# See note  in Statistical Rethinking 2nd ed for an explation of why to subtract post2.max()
post2 = np.exp(post2 - post2.max())
post2 /= post2.sum()

post2_flatten = post2.flatten()
indicies = np.random.choice(post2_flatten.size, p=post2_flatten, size=10000)
sample2_rows = np.unravel_index(indicies, post2.shape)

sample2_mu = mu_list[sample2_rows[0]]
sample2_sigma = sigma_list[sample2_rows[1]]

# %%
fig, ax = plt.subplots(ncols=2, figsize=(9, 5))

ax[0].scatter(
    x=mu_list[sampled_indices_2d[0]],
    y=sigma_list[sampled_indices_2d[1]],
    alpha=0.1,
    marker=".",
    linewidth=0.1,
)
az.plot_posterior(sample2_sigma, ax=ax[1])
fig.tight_layout()

# %% [markdown]
# ### 4.3.5. Finding the posterior distribution with quadratic approximation

# %% [markdown]
# The follwing function is based on [quap5](https://pypi.org/project/quad5/).

# %%
start = {"mu": d2.height.mean(), "sigma": d2.height.std()}

# %%
with pm.Model() as model_m4_1:
    mu = pm.Normal("mu", mu=178, sigma=20)
    sigma = pm.Uniform("sigma", 0, 50)
    height = pm.Normal("height", mu=mu, sigma=sigma, observed=d2.height)
    custom_step_m4_1 = quad5.QuadraticApproximation([mu, sigma], model_m4_1)
    m4_1 = pm.sample(draws=1000, chains=4, tune=100, step=custom_step_m4_1)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carsten/Dev/Rethinking/.venv/lib/python3.10/site-packages/pymc/model/core.py:565: FutureWarning: Model.model property is deprecated. Just use Model.
#   warnings.warn("Model.model property is deprecated. Just use Model.", FutureWarning)
# /Users/carsten/Dev/Rethinking/.venv/lib/python3.10/site-packages/pytensor/configparser.py:47: FutureWarning: hessian will stop negating the output in a future version of PyMC.
# To suppress this warning set `negate_output=False`
#   return f(*args, **kwargs)
# Multiprocess sampling (4 chains in 4 jobs)
# QuadraticApproximation: [mu, sigma]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 100 tune and 1_000 draw iterations (400 + 4_000 draws total) took 6 seconds.

# %%
m4_1
# Out:
# Inference data with groups:
# 	> posterior
# 	> observed_data

# %%
def precis(samples, var_names=None):
    return az.summary(samples, kind="stats", hdi_prob=0.89, var_names=var_names).round(2)

# %%
precis(m4_1)
# Out:
#          mean    sd  hdi_5.5%  hdi_94.5%
# mu     154.61  0.42    153.93     155.23
# sigma    7.74  0.29      7.25       8.19

# %%
with pm.Model() as model_m4_2:
    mu = pm.Normal("mu", mu=178, sigma=0.1)
    sigma = pm.Uniform("sigma", 0, 50)
    height = pm.Normal("height", mu=mu, sigma=sigma, observed=d2.height)
    custom_step_m4_2 = quad5.QuadraticApproximation([mu, sigma], model_m4_2)
    m4_2 = pm.sample(draws=1000, chains=4, tune=100, step=custom_step_m4_2)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carsten/Dev/Rethinking/.venv/lib/python3.10/site-packages/pymc/model/core.py:565: FutureWarning: Model.model property is deprecated. Just use Model.
#   warnings.warn("Model.model property is deprecated. Just use Model.", FutureWarning)
# /Users/carsten/Dev/Rethinking/.venv/lib/python3.10/site-packages/pytensor/configparser.py:47: FutureWarning: hessian will stop negating the output in a future version of PyMC.
# To suppress this warning set `negate_output=False`
#   return f(*args, **kwargs)
# Multiprocess sampling (4 chains in 4 jobs)
# QuadraticApproximation: [mu, sigma]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 100 tune and 1_000 draw iterations (400 + 4_000 draws total) took 6 seconds.

# %%
precis(m4_2)
# Out:
#          mean    sd  hdi_5.5%  hdi_94.5%
# mu     177.86  0.10    177.70     178.02
# sigma   24.53  0.93     23.09      26.05

# %%
az.plot_pair(m4_1, kind="kde", marginals=True, figsize=(6, 6));

# %%
def vcov(custom_step):
    return custom_step.covariance

# %%
vcov(custom_step_m4_1)
# Out:
# array([[0.16973961, 0.00021803],
#        [0.00021803, 0.08490583]])

# %%
def cov2cor(c: np.ndarray) -> np.ndarray:
    """
    Return a correlation matrix given a covariance matrix.
    : c = covariance matrix
    """
    D = np.zeros(c.shape)
    np.fill_diagonal(D, np.sqrt(np.diag(c)))
    invD = inv(D)
    return invD @ c @ invD

# %%
cov2cor(vcov(custom_step_m4_1))
# Out:
# array([[1.        , 0.00181618],
#        [0.00181618, 1.        ]])

# %%
# See https://python.arviz.org/en/stable/getting_started/CreatingInferenceData.html#from-dataframe
def convert_to_inference_data(df):
    df["chain"] = 1
    df["draw"] = np.arange(len(df), dtype=int)
    df = df.set_index(["chain", "draw"])
    xdata = xr.Dataset.from_dataframe(df)
    idata = az.InferenceData(posterior=xdata)
    return idata


# Add the `to_inference_data()` method to the DataFrame class
pd.DataFrame.convert_to_inference_data = convert_to_inference_data

# %%
custom_step_m4_1.covariance
# Out:
# array([[0.16973961, 0.00021803],
#        [0.00021803, 0.08490583]])

# %%
def extract_samples(custom_step, size=10000):
    samples = rng.multivariate_normal(mean=custom_step.mode, cov=custom_step.covariance, size=size)
    df = pd.DataFrame({"mu": samples[:, 0], "sigma": samples[:, 1]})
    return df.convert_to_inference_data()

# %%
post = extract_samples(custom_step_m4_1)

# %%
precis(post)
# Out:
#          mean    sd  hdi_5.5%  hdi_94.5%
# mu     154.60  0.42    153.94     155.28
# sigma    7.73  0.29      7.25       8.18

# %% [markdown]
# ### 4.4.1. The linear model strategy.

# %%
N = 100
x = np.linspace(d2.weight.min(), d2.weight.max())
xbar = d2.weight.mean()

# %%
fig, ax = plt.subplots(ncols=2, figsize=(10, 6), sharey=True)

a = st.norm(loc=178, scale=20).rvs(N)
b = st.norm(loc=0, scale=10).rvs(N)
for i in range(N):
    ax[0].plot(x, a[i] + b[i] * (x - xbar), color="black", alpha=0.1)
ax[0].axhline(272, color="black")
ax[0].axhline(0, color="black", linestyle="--")
ax[0].set(xlabel="weight", ylabel="height", ylim=(-100, 400))

# Sample from new prior
a = st.norm(loc=178, scale=20).rvs(N)
b = st.lognorm(scale=np.exp(0), s=1).rvs(N)

# Plot regression lines from the prior
for i in range(N):
    ax[1].plot(x, a[i] + b[i] * (x - xbar), color="black", alpha=0.1)
ax[1].axhline(272, color="black")
ax[1].axhline(0, color="black", linestyle="--")
ax[1].set(xlabel="weight", ylabel="height", ylim=(-100, 400))

fig.tight_layout()

# %%
xbar = d2.weight.mean()

# %%
with pm.Model() as model_m4_3:

    weight = pm.ConstantData("w", d2.weight, dims="obs_id")

    sigma = pm.Uniform("sigma", 0, 10)
    a = pm.Normal("a", 178, 20)
    b = pm.LogNormal("b", 0, 1)

    mu = pm.Deterministic("mu", a + b * (weight - xbar), dims="obs_id")
    # likelihood
    likelihood = pm.Normal(
        "h", mu=mu, sigma=sigma, observed=d2["height"], dims="obs_id"
    )

    custom_step_m4_3 = quad5.QuadraticApproximation([a, b, sigma], model_m4_3)
    m4_3 = pm.sample(draws=1000, chains=1, tune=100, step=custom_step_m4_3)
# Out:
# /Users/carsten/Dev/Rethinking/.venv/lib/python3.10/site-packages/pymc/data.py:273: FutureWarning: ConstantData is deprecated. All Data variables are now mutable. Use Data instead.
#   warnings.warn(
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carsten/Dev/Rethinking/.venv/lib/python3.10/site-packages/pymc/model/core.py:565: FutureWarning: Model.model property is deprecated. Just use Model.
#   warnings.warn("Model.model property is deprecated. Just use Model.", FutureWarning)
# /Users/carsten/Dev/Rethinking/.venv/lib/python3.10/site-packages/pytensor/configparser.py:47: FutureWarning: hessian will stop negating the output in a future version of PyMC.
# To suppress this warning set `negate_output=False`
#   return f(*args, **kwargs)
# Sequential sampling (1 chains in 1 job)
# QuadraticApproximation: [a, b, sigma]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 1 chain for 100 tune and 1_000 draw iterations (100 + 1_000 draws total) took 4 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %%
m4_3
# Out:
# Inference data with groups:
# 	> posterior
# 	> observed_data
# 	> constant_data

# %%
precis(m4_3, var_names="~mu")
# Out:
#          mean    sd  hdi_5.5%  hdi_94.5%
# a      154.60  0.28    154.21     155.09
# b        0.91  0.04      0.84       0.96
# sigma    5.07  0.20      4.74       5.36

# %%
np.around(custom_step_m4_3.covariance, 3)
# Out:
# array([[ 0.073, -0.   ,  0.   ],
#        [-0.   ,  0.002, -0.   ],
#        [ 0.   , -0.   ,  0.037]])

# %%
posterior_mean = m4_3.mean()

# %%
fig, ax = plt.subplots()
a = posterior_mean.posterior["a"].values
b = posterior_mean.posterior["b"].values
x = np.linspace(d2.weight.min(), d2.weight.max(), 10)
y = a + b * (x - xbar)
ax.scatter(d2.weight, d2.height, label="data", facecolor="none", edgecolor="C0")
ax.plot(x, y, label="posterior mean", color="black")
ax.set(xlabel="weight", ylabel="height", title="Mean regression line of the posterior");

# %%
weight_numpy = d2["weight"].to_numpy()
height_numpy = d2["height"].to_numpy()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10), sharey=True, sharex=True)
for N, ax in zip((10, 50, 150, 352), axes.flatten()):
    idx = np.random.choice(len(weight_numpy), N)
    weight_, height_ = weight_numpy[idx], height_numpy[idx]

    xbar = np.mean(weight_)

    with pm.Model() as m:
        sigma = pm.Uniform("sigma", 0, 10)
        a = pm.Normal("a", 178, 20)
        b = pm.LogNormal("b", 0, 1)
        mu = pm.Deterministic("mu", a + b * (weight_ - xbar))
        # Define likelihood
        likelihood = pm.Normal("w", mu=mu, sigma=sigma, observed=height_)
        custom_step = quad5.QuadraticApproximation([a, b, sigma], m)
        idata = pm.sample(draws=1000, chains=1, tune=100, step=custom_step)

    sample_size = 20
    samples = az.extract(idata, num_samples=sample_size, rng=True)

    ax.scatter(weight_, height_, facecolor="none", edgecolor="C0")

    for i in range(sample_size):
        a = samples.get("a")[i].values
        b = samples.get("b")[i].values
        x = np.linspace(weight_numpy.min(), weight_numpy.max(), 10)
        y = a + b * (x - xbar)
        ax.plot(x, y, color="black", alpha=0.2)
    ax.set(xlabel="weight", ylabel="height", title=f"N = {N}")

fig.tight_layout()
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carsten/Dev/Rethinking/.venv/lib/python3.10/site-packages/pymc/model/core.py:565: FutureWarning: Model.model property is deprecated. Just use Model.
#   warnings.warn("Model.model property is deprecated. Just use Model.", FutureWarning)
# /Users/carsten/Dev/Rethinking/.venv/lib/python3.10/site-packages/pytensor/configparser.py:47: FutureWarning: hessian will stop negating the output in a future version of PyMC.
# To suppress this warning set `negate_output=False`
#   return f(*args, **kwargs)
# Sequential sampling (1 chains in 1 job)
# QuadraticApproximation: [a, b, sigma]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 1 chain for 100 tune and 1_000 draw iterations (100 + 1_000 draws total) took 4 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carsten/Dev/Rethinking/.venv/lib/python3.10/site-packages/pymc/model/core.py:565: FutureWarning: Model.model property is deprecated. Just use Model.
#   warnings.warn("Model.model property is deprecated. Just use Model.", FutureWarning)
# /Users/carsten/Dev/Rethinking/.venv/lib/python3.10/site-packages/pytensor/configparser.py:47: FutureWarning: hessian will stop negating the output in a future version of PyMC.
# To suppress this warning set `negate_output=False`
#   return f(*args, **kwargs)
# Sequential sampling (1 chains in 1 job)
# QuadraticApproximation: [a, b, sigma]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 1 chain for 100 tune and 1_000 draw iterations (100 + 1_000 draws total) took 4 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carsten/Dev/Rethinking/.venv/lib/python3.10/site-packages/pymc/model/core.py:565: FutureWarning: Model.model property is deprecated. Just use Model.
#   warnings.warn("Model.model property is deprecated. Just use Model.", FutureWarning)
# /Users/carsten/Dev/Rethinking/.venv/lib/python3.10/site-packages/pytensor/configparser.py:47: FutureWarning: hessian will stop negating the output in a future version of PyMC.
# To suppress this warning set `negate_output=False`
#   return f(*args, **kwargs)
# Sequential sampling (1 chains in 1 job)
# QuadraticApproximation: [a, b, sigma]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 1 chain for 100 tune and 1_000 draw iterations (100 + 1_000 draws total) took 4 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carsten/Dev/Rethinking/.venv/lib/python3.10/site-packages/pymc/model/core.py:565: FutureWarning: Model.model property is deprecated. Just use Model.
#   warnings.warn("Model.model property is deprecated. Just use Model.", FutureWarning)
# /Users/carsten/Dev/Rethinking/.venv/lib/python3.10/site-packages/pytensor/configparser.py:47: FutureWarning: hessian will stop negating the output in a future version of PyMC.
# To suppress this warning set `negate_output=False`
#   return f(*args, **kwargs)
# Sequential sampling (1 chains in 1 job)
# QuadraticApproximation: [a, b, sigma]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 1 chain for 100 tune and 1_000 draw iterations (100 + 1_000 draws total) took 4 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %%
xbar = d2.weight.mean()
a = m4_3.get("posterior")["a"].values
b = m4_3.get("posterior")["b"].values
y = a + b * (50 - xbar)

# %%
fig, ax = plt.subplots(ncols=2, figsize=(8, 3), sharex=True, sharey=True)
az.plot_kde(y[0], ax=ax[0], backend_kwargs={"title": "foo"})
ax[1].hist(y[0], density=True, bins=100, histtype="step")
fig.tight_layout()

# %%
az.hdi(y[0])
# Out:
# array([158.53803093, 159.82062899])

# %%
pm.sample_posterior_predictive(m4_3, model=model_m4_3, extend_inferencedata=True)
# Out:
# Sampling: [h]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Inference data with groups:
# 	> posterior
# 	> posterior_predictive
# 	> observed_data
# 	> constant_data

# %% [markdown]
# #### Figure 4.10

# %% [markdown]
# R code 4.59 - 4.62

# %%
az.plot_lm(
    idata=m4_3,
    x="w",
    y="h",
    y_model="mu",
    kind_pp="hdi",
    kind_model="hdi",
    figsize=(10, 8),
);

# %%
# %watermark --iversions
# Out:
# arviz     : 0.18.0
# pandas    : 2.2.2
# ipykernel : 6.29.4
# quad5     : 0.1.0
# pymc      : 5.15.0
# sys       : 3.10.13 | packaged by conda-forge | (main, Oct 26 2023, 18:09:17) [Clang 16.0.6 ]
# scipy     : 1.12.0
# watermark : 2.4.3
# numpy     : 1.26.4
# matplotlib: 3.9.0
# preliz    : 0.7.0
# xarray    : 2024.5.0
# debugpy   : 1.8.1
# seaborn   : 0.13.2
